# %% [markdown]
# ## Что делать?
# В этой домашке надо построить кучу графиков и описать, что на них происходит. Чем подробнее вы опишете - тем лучше.
# Для вдохновения можно использовать презентацию по графикам и материалы из неё.
#
# Оценка - тут всё просто: одно задание - 1 балл

# %%
# !ls
# Out:
# Graphs_homework.ipynb     booking_data_homework.csv lesson_4.ipynb

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('booking_data_homework.csv')
df
# Out:
#      arrival_date destination_region           destination_city  \
# 0      2019-07-06      International                      Kundu
# 1      2019-09-09      International                       Jeju
# 2      2019-04-17             Russia                Arkhangelsk
# 3      2019-07-17     Western Europe                      Paris
# 4      2019-04-22    Southern Europe                     Zagreb
# 5      2019-04-20      International                   Shenzhen
# 6      2019-06-24                CIS                       Baku
# 7      2019-08-27    Southern Europe                    Bologna
# 8      2019-04-20     Western Europe                     Berlin
# 9      2019-05-24    Southern Europe                     Naples
# 10     2019-05-01    Southern Europe                       Rome
# 11     2019-05-08     Western Europe                     London
# 12     2019-08-05     Western Europe                      Luton
# 13     2019-07-01      International                Los Angeles
# ...

# %% [markdown]
# ## Задание 1
# Посмотрим, партнёры из каких регионов делали бронирования в этот день (plt.bar())

# %%
# делаем небольшие преобразования с данными, записываем переменную partner_geo и выводим её
partner_geo = df['partner_geo'].value_counts()
partner_geo
# Out:
# Russia             4651
# International       655
# CIS                 611
# Arabia              335
# Balkans             255
# Southern Europe     245
# Baltic States       234
# Visegrad Group      220
# Western Europe      187
# Name: partner_geo, dtype: int64

# %%
# а теперь уже строим график. Подсказка: вам нужна следующая строка:
# plt.bar(partner_geo.index, partner_geo, width, color='#d62728')
# а также нужно опдписать оси, легенду и всё-всё-всё

# %% [markdown]
# ## Задание 2
# Давайте посмотрим, как у нас выглядит распределение цен (plt.hist(cumulative=False)).

# %% [markdown]
# ## Задание 3
# Хм, выглядит не очень. Давайте попробуем сгруппировать цены в интервалы покрупнее (bar = 1000)

# %% [markdown]
# ## Задание 4
# Давайте посмотрим ещё крупнее, выберите интервал самостоятельно.

# %% [markdown]
# ## Задание 5
# Опишите получившуюся гистограмму

# %% [markdown]
# ## Задание 6
# Давайте сравним распределения цен по бизнес-поездкам и поездкам с целью отдыха (plt.plot([x], y), разными цветами надо покрасить business и leisure.

# %% [markdown]
# ## Задание 7
# Что тут видно?

# %% [markdown]
# ## Задание 8
# Постройте график зависимости стоимости бронирования от длительности проживания (вам поможет plt.scatter()).

# %% [markdown]
# ## Задание 9
# Опишите полученный график

# %% [markdown]
# ## Задание 10
# Постройте осмысленный plt.boxplot() на имеющихся данных. Расскажите, что показывает этот график
