# %% [markdown]
# # Вещественные числа и строки
#
# Для части задачек придётся заняться самостоятельным гуглением.
# Вот ещё можно почитать, если возникнут трудности с домашкой:
#
# [Экспоненциальная запись](https://ru.wikipedia.org/wiki/%D0%AD%D0%BA%D1%81%D0%BF%D0%BE%D0%BD%D0%B5%D0%BD%D1%86%D0%B8%D0%B0%D0%BB%D1%8C%D0%BD%D0%B0%D1%8F_%D0%B7%D0%B0%D0%BF%D0%B8%D1%81%D1%8C#.D0.9A.D0.BE.D0.BC.D0.BF.D1.8C.D1.8E.D1.82.D0.B5.D1.80.D0.BD.D1.8B.D0.B9_.D1.81.D0.BF.D0.BE.D1.81.D0.BE.D0.B1_.D1.8D.D0.BA.D1.81.D0.BF.D0.BE.D0.BD.D0.B5.D0.BD.D1.86.D0.B8.D0.B0.D0.BB.D1.8C.D0.BD.D0.BE.D0.B9_.D0.B7.D0.B0.D0.BF.D0.B8.D1.81.D0.B8)
#
# [Таблица ASCII символов](http://ascii.cl/)

# %% [markdown]
# ### Задание 1
#
# Составьте выражение для вычисления в интерпретаторе Python 3 и вставьте в поле ответа результат вычисления:
#
# 2014.0 в степени 14

# %% [markdown]
# ### Задание 2
#
# Выведите выражение значения которых равны True. Напишите, почему:
#
# "239" < "30" and 239 < 30
#
# "239" < "30" and 239 > 30
#
# "239" > "30" and 239 < 30
#
# "239" > "30" and 239 > 30

# %% [markdown]
# ### Задание 3
#
# Укажите результат выражения:
#
# `"8768" + "111"`
#
# Попробуйте получить ответ без использования интерпретатора.

# %% [markdown]
# ### Задание 4
#
# Есть строка s = "abcdefghijk".
# В поле ответа через пробел запишите строки (без кавычек), полученные в результате следующих операций:
#
# `s = 'abcdefghijk'
# s[3:6]
# s[:6]
# s[3:]
# s[::-1]
# s[-3:]
# s[:-6]
# s[-1:-10:-2]`
#
# Попробуйте найти ответ к этой задаче, не используя интерпретатор Python. Если без интерпретатора решить не получается, разберитесь, почему выводятся именно такие строки в каждом из вариантов.

# %% [markdown]
# ### Задание 5
#
# Дано неотрицательное вещественное число X, округлите его по всем известным вам правилам.

# %% [markdown]
# ### Задание 6
#
# Дана строка. Если в этом числе буква f встречается только один раз, выведите её индекс. Если она встречается два и более раз, выведите индекс её первого и последнего появления через пробел. Если буква f в данной строке не встречается, ничего не выводите.
#
# Для решения задачи могут быть полезны методы:
#
# string.find(substring) - возвращает позицию самого левого вхождения подстроки substring в строку string или -1, если подстрока не найдена
#
# string.rfind(substring) - возвращает позицию самого правого вхождения подстроки substring в строку string или -1, если подстрока не найдена

# %% [markdown]
# ### Задание 7
#
# Вы СМИ. Чтобы избежать штрафа и блокировки, во всех новостях надо заменить слово "самоубийство" на слово "Роскомнадзор". Напишите код, который вам в этом поможет.
#
# Бонусом будет - если вы замените это слово во всех регистрах. (тут придётся погуглить)

# %% [markdown]
# ### Задание 8
#
# В форме интернет-магазина пользователю нужно ввести свой номер телефона. Номер телефона состоит из 10 цифр, однако некоторые пользователи вводят его в формате +7123456789, некоторые - 8123456789, а некоторые и вовсе вводят только 9 цифр (без первой) 123456789.
#
# Вам необходимо привести номер к стандарту +7123456789
